# %%
# Mount Google Drive in Colab

# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Import Libraries

import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf

# %%
# Get Dataset from Google Drive

# !unzip "/content/drive/MyDrive/Drowsiness Dataset/Generative Dataset.zip" -d "Generative Dataset"

# %%
# Loading Dataset

import pathlib
data_dir = pathlib.Path("/content/Generative Dataset/With Generative")

# %%
image_count = len(list(data_dir.glob('*/*.png')))
print(image_count)
# Out:
# 2615

# %%
drowsy = list(data_dir.glob('Drowsy/*'))
PIL.Image.open(str(drowsy[1]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=224x224>

# %%
# Set input parameters

batch_size = 32
img_height = 224
img_width = 224

# %%
# Split Dataset

train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="training",
  label_mode="binary",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2615 files belonging to 2 classes.
# Using 1831 files for training.

# %%
# Split Dataset

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="validation",
  label_mode="binary",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2615 files belonging to 2 classes.
# Using 784 files for validation.

# %%
# Split Dataset into validation and test

val_batches = tf.data.experimental.cardinality(val_ds)
val_ds = val_ds.shuffle(buffer_size=1000)
test_ds = val_ds.take(val_batches // 2)
val_ds = val_ds.skip(val_batches // 2)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(val_ds))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_ds))
# Out:
# Number of validation batches: 13
# Number of test batches: 12

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Drowsy', 'Non Drowsy']

# %%
# Get shape of input

for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 224, 224, 3)
# (32, 1)

# %%
## Loading VGG16 model

from tensorflow.keras.applications.vgg16 import VGG16
base_model = VGG16(weights= "imagenet", include_top=False, input_shape=(224, 224, 3))
base_model.trainable=False  ## Not trainable weights

# %%
# Setup model structure

from tensorflow.keras import layers, models, regularizers
model=models.Sequential([
    layers.Rescaling(1./255),
    base_model,
    # layers.Flatten(),
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.L2(1e-4)),
    tf.keras.layers.Dropout(0.2),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.L2(1e-4)),
    tf.keras.layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid')
])

# %%
# Set learning rate, optimizer and metrics

base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=[tf.keras.metrics.BinaryAccuracy(threshold=0.5, name='accuracy'),
                       tf.keras.metrics.Precision(name='precision'),
                       tf.keras.metrics.Recall(name='recall')]
              )

# %%
# Define Early Stopping - Unused in final training

from tensorflow.keras import callbacks
es_val_loss = callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.01,
    patience=1,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)
es_val_accuracy = callbacks.EarlyStopping(
    monitor="val_accuracy",
    min_delta=0,
    patience=1,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
# Train Model

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=15
  # callbacks=[es_val_loss, es_val_accuracy]
)
# Out:
# Epoch 1/15
# 58/58 [==============================] - 14s 199ms/step - loss: 0.7202 - accuracy: 0.5467 - precision: 0.5368 - recall: 0.5903 - val_loss: 0.6940 - val_accuracy: 0.7100 - val_precision: 0.7857 - val_recall: 0.5266
# Epoch 2/15
# 58/58 [==============================] - 12s 200ms/step - loss: 0.7106 - accuracy: 0.5582 - precision: 0.5530 - recall: 0.5426 - val_loss: 0.6656 - val_accuracy: 0.7236 - val_precision: 0.7018 - val_recall: 0.7537
# Epoch 3/15
# 58/58 [==============================] - 12s 194ms/step - loss: 0.6667 - accuracy: 0.6439 - precision: 0.6369 - recall: 0.6467 - val_loss: 0.6307 - val_accuracy: 0.7812 - val_precision: 0.7853 - val_recall: 0.7500
# Epoch 4/15
# 58/58 [==============================] - 12s 194ms/step - loss: 0.6356 - accuracy: 0.6745 - precision: 0.6912 - recall: 0.6146 - val_loss: 0.6001 - val_accuracy: 0.7950 - val_precision: 0.8000 - val_recall: 0.7921
# Epoch 5/15
# 58/58 [==============================] - 12s 195ms/step - loss: 0.5996 - accuracy: 0.7307 - precision: 0.7506 - recall: 0.6800 - val_loss: 0.5747 - val_accuracy: 0.7650 - val_precision: 0.7561 - val_recall: 0.7789
# Epoch 6/15
# 58/58 [==============================] - 14s 223ms/step - loss: 0.5695 - accuracy: 0.7537 - precision: 0.7646 - recall: 0.7231 - val_loss: 0.5235 - val_accuracy: 0.8341 - val_precision: 0.8730 - val_recall: 0.7857
# Epoch 7/15
# 58/58 [==============================] - 14s 228ms/step - loss: 0.5232 - accuracy: 0.7886 - precision: 0.8101 - recall: 0.7464 - val_loss: 0.4835 - val_accuracy: 0.8300 - val_precision: 0.8342 - val_recall: 0.8083
# Epoch 8/15
# 58/58 [==============================] - 13s 212ms/step - loss: 0.4788 - accuracy: 0.8285 - precision: 0.8535 - recall: 0.7874 - val_loss: 0.4236 - val_accuracy: 0.8918 - val_precision: 0.9204 - val_recall: 0.8645
# Epoch 9/15
# 58/58 [==============================] - 13s 225ms/step - loss: 0.4457 - accuracy: 0.8454 - precision: 0.8588 - recall: 0.8217 - val_loss: 0.3911 - val_accuracy: 0.9375 - val_precision: 0.9200 - val_recall: 0.9534
# Epoch 10/15
# 58/58 [==============================] - 12s 206ms/step - loss: 0.3966 - accuracy: 0.8798 - precision: 0.8894 - recall: 0.8638 - val_loss: 0.3459 - val_accuracy: 0.9325 - val_precision: 0.9536 - val_recall: 0.9113
# Epoch 11/15
# 58/58 [==============================] - 11s 190ms/step - loss: 0.3540 - accuracy: 0.9050 - precision: 0.9137 - recall: 0.8915 - val_loss: 0.3129 - val_accuracy: 0.9450 - val_precision: 0.9296 - val_recall: 0.9659
# Epoch 12/15
# 58/58 [==============================] - 12s 195ms/step - loss: 0.3192 - accuracy: 0.9192 - precision: 0.9190 - recall: 0.9169 - val_loss: 0.2868 - val_accuracy: 0.9525 - val_precision: 0.9423 - val_recall: 0.9655
# Epoch 13/15
# 58/58 [==============================] - 13s 213ms/step - loss: 0.2894 - accuracy: 0.9328 - precision: 0.9212 - recall: 0.9446 - val_loss: 0.2472 - val_accuracy: 0.9495 - val_precision: 0.9273 - val_recall: 0.9761
# Epoch 14/15
# 58/58 [==============================] - 13s 215ms/step - loss: 0.2557 - accuracy: 0.9345 - precision: 0.9345 - recall: 0.9324 - val_loss: 0.2310 - val_accuracy: 0.9600 - val_precision: 0.9406 - val_recall: 0.9794
# Epoch 15/15
# 58/58 [==============================] - 13s 212ms/step - loss: 0.2361 - accuracy: 0.9563 - precision: 0.9537 - recall: 0.9579 - val_loss: 0.1952 - val_accuracy: 0.9700 - val_precision: 0.9652 - val_recall: 0.9749

# %%
# Graph Plots

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Save model to Google Drive

# model.save('/content/drive/MyDrive/Drowsiness Dataset/generative_dataset_model_3.keras')

# %%
# Predict on test set

results = model.evaluate(x=test_ds)
# Out:
# 12/12 [==============================] - 3s 133ms/step - loss: 0.2044 - accuracy: 0.9714 - precision: 0.9836 - recall: 0.9574
